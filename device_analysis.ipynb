# %% [markdown]
# #importing dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/luminar/data science/project/ml project/archive (5).zip")
df.head()
# Out:
#   device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0        Honor  Android        14.50  yes   no            13.0
# 1        Honor  Android        17.30  yes  yes            13.0
# 2        Honor  Android        16.69  yes  yes            13.0
# 3        Honor  Android        25.50  yes  yes            13.0
# 4        Honor  Android        15.32  yes   no            13.0
#
#    front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0              5.0             64.0  3.0   3020.0   146.0          2020
# 1             16.0            128.0  8.0   4300.0   213.0          2020
# 2              8.0            128.0  8.0   4200.0   213.0          2020
# 3              8.0             64.0  6.0   7250.0   480.0          2020
# 4              8.0             64.0  3.0   5000.0   185.0          2020
#
#    days_used  normalized_used_price  normalized_new_price
# 0        127               4.307572              4.715100
# ...

# %% [markdown]
# *device_brand: Name of manufacturing brand
#
# *os: OS on which the device runs
#
# *screen_size: Size of the screen in cm
#
# *4g: Whether 4G is available or not
#
# *5g: Whether 5G is available or not
#
# *front_camera_mp: Resolution of the rear camera in megapixels
#
# *back_camera_mp: Resolution of the front camera in megapixels
#
# *internal_memory: Amount of internal memory (ROM) in GB
#
# *ram: Amount of RAM in GB
#
# *battery: Energy capacity of the device battery in mAh
#
# *weight: Weight of the device in grams
#
# *release_year: Year when the device model was released
#
# *days_used: Number of days the used/refurbished device has been used
#
# *normalized_new_price: Normalized price of a new device of the same model
#
# *normalized_used_price (TARGET): Normalized price of the used/refurbished device

# %%
df.describe()
# Out:
#        screen_size  rear_camera_mp  front_camera_mp  internal_memory  \
# count  3454.000000     3275.000000      3452.000000      3450.000000
# mean     13.713115        9.460208         6.554229        54.573099
# std       3.805280        4.815461         6.970372        84.972371
# min       5.080000        0.080000         0.000000         0.010000
# 25%      12.700000        5.000000         2.000000        16.000000
# 50%      12.830000        8.000000         5.000000        32.000000
# 75%      15.340000       13.000000         8.000000        64.000000
# max      30.710000       48.000000        32.000000      1024.000000
#
#                ram      battery       weight  release_year    days_used  \
# count  3450.000000  3448.000000  3447.000000   3454.000000  3454.000000
# mean      4.036122  3133.402697   182.751871   2015.965258   674.869716
# std       1.365105  1299.682844    88.413228      2.298455   248.580166
# ...

# %%
df.shape
# Out:
# (3454, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   object
#  1   os                     3454 non-null   object
#  2   screen_size            3454 non-null   float64
#  3   4g                     3454 non-null   object
#  4   5g                     3454 non-null   object
#  5   rear_camera_mp         3275 non-null   float64
#  6   front_camera_mp        3452 non-null   float64
#  7   internal_memory        3450 non-null   float64
#  8   ram                    3450 non-null   float64
#  9   battery                3448 non-null   float64
#  10  weight                 3447 non-null   float64
#  11  release_year           3454 non-null   int64
#  12  days_used              3454 non-null   int64
#  13  normalized_used_price  3454 non-null   float64
# ...

# %%
df.isna().any()
# Out:
# device_brand             False
# os                       False
# screen_size              False
# 4g                       False
# 5g                       False
# rear_camera_mp            True
# front_camera_mp           True
# internal_memory           True
# ram                       True
# battery                   True
# weight                    True
# release_year             False
# days_used                False
# normalized_used_price    False
# normalized_new_price     False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# device_brand               0
# os                         0
# screen_size                0
# 4g                         0
# 5g                         0
# rear_camera_mp           179
# front_camera_mp            2
# internal_memory            4
# ram                        4
# battery                    6
# weight                     7
# release_year               0
# days_used                  0
# normalized_used_price      0
# normalized_new_price       0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# device_brand             0.000000
# os                       0.000000
# screen_size              0.000000
# 4g                       0.000000
# 5g                       0.000000
# rear_camera_mp           5.182397
# front_camera_mp          0.057904
# internal_memory          0.115808
# ram                      0.115808
# battery                  0.173712
# weight                   0.202664
# release_year             0.000000
# days_used                0.000000
# normalized_used_price    0.000000
# normalized_new_price     0.000000
# dtype: float64

# %% [markdown]
# #Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#line plot

from matplotlib import rcParams
rcParams['figure.figsize']=10,10
sns.lmplot(x='normalized_used_price',y='normalized_new_price',col='device_brand',data=df)
plt.show()

# %%
#heatmap

sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-11-95d25f594750>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.histplot(df['device_brand'])
# Out:
# <Axes: xlabel='device_brand', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))

sns.histplot(df['os'])                         #mostly android
# Out:
# <Axes: xlabel='os', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))

sns.histplot(df["4g"])
plt.show()

plt.figure(figsize=(5,5))
sns.histplot(df["5g"])
# Out:
# <Axes: xlabel='5g', ylabel='Count'>

# %% [markdown]
# ^only few phones have 5g

# %%
sns.scatterplot(data=df,x='screen_size',y="normalized_used_price")                     #larger the size higher the price
# Out:
# <Axes: xlabel='screen_size', ylabel='normalized_used_price'>

# %% [markdown]
# #cleaning

# %%
df.isna().any()
# Out:
# device_brand             False
# os                       False
# screen_size              False
# 4g                       False
# 5g                       False
# rear_camera_mp            True
# front_camera_mp           True
# internal_memory           True
# ram                       True
# battery                   True
# weight                    True
# release_year             False
# days_used                False
# normalized_used_price    False
# normalized_new_price     False
# dtype: bool

# %%
df['rear_camera_mp'].unique()
# Out:
# array([13.  ,  8.  ,  5.  , 10.5 ,  3.15,   nan,  2.  , 16.  ,  0.3 ,
#        12.  , 14.5 , 48.  ,  3.  , 21.  ,  1.3 , 13.1 , 24.  ,  0.08,
#        20.7 , 23.  ,  1.  , 18.  , 12.2 , 12.3 , 20.  , 20.2 ,  4.  ,
#        12.5 , 10.  ,  6.5 ,  6.7 , 41.  , 20.1 , 12.6 , 16.3 , 22.6 ,
#        19.  , 21.5 , 21.2 ,  8.1 ,  1.2 , 22.5 ])

# %%
df['rear_camera_mp'].value_counts()
# Out:
# 13.00    1035
# 8.00      755
# 5.00      546
# 12.00     189
# 2.00      171
# 16.00     154
# 3.15      122
# 0.30       69
# 10.50      30
# 1.30       26
# 23.00      19
# 21.00      19
# 20.70      16
# 20.00      13
# 14.50      13
# 12.20      12
# 4.00       10
# 12.30       9
# 19.00       8
# 8.10        7
# 13.10       6
# 10.00       6
# 24.00       5
# 3.00        5
# 12.50       4
# 48.00       4
# 6.50        4
# 6.70        4
# 21.20       2
# 21.50       1
# 1.20        1
# 16.30       1
# 22.60       1
# 18.00       1
# 12.60       1
# 20.10       1
# 41.00       1
# 20.20       1
# 1.00        1
# 0.08        1
# 22.50       1
# Name: rear_camera_mp, dtype: int64

# %%
df=df.fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# device_brand             0
# os                       0
# screen_size              0
# 4g                       0
# 5g                       0
# rear_camera_mp           0
# front_camera_mp          0
# internal_memory          0
# ram                      0
# battery                  0
# weight                   0
# release_year             0
# days_used                0
# normalized_used_price    0
# normalized_new_price     0
# dtype: int64

# %%
df.dtypes
# Out:
# device_brand              object
# os                        object
# screen_size              float64
# 4g                        object
# 5g                        object
# rear_camera_mp           float64
# front_camera_mp          float64
# internal_memory          float64
# ram                      float64
# battery                  float64
# weight                   float64
# release_year               int64
# days_used                  int64
# normalized_used_price    float64
# normalized_new_price     float64
# dtype: object

# %%
df['device_brand'].unique()
# Out:
# array(['Honor', 'Others', 'HTC', 'Huawei', 'Infinix', 'Lava', 'Lenovo',
#        'LG', 'Meizu', 'Micromax', 'Motorola', 'Nokia', 'OnePlus', 'Oppo',
#        'Realme', 'Samsung', 'Vivo', 'Xiaomi', 'ZTE', 'Apple', 'Asus',
#        'Coolpad', 'Acer', 'Alcatel', 'BlackBerry', 'Celkon', 'Gionee',
#        'Google', 'Karbonn', 'Microsoft', 'Panasonic', 'Sony', 'Spice',
#        'XOLO'], dtype=object)

# %%
df['device_brand'].value_counts()
# Out:
# Others        502
# Samsung       341
# Huawei        251
# LG            201
# Lenovo        171
# ZTE           140
# Xiaomi        132
# Oppo          129
# Asus          122
# Alcatel       121
# Micromax      117
# Vivo          117
# Honor         116
# HTC           110
# Nokia         106
# Motorola      106
# Sony           86
# Meizu          62
# Gionee         56
# Acer           51
# XOLO           49
# Panasonic      47
# Realme         41
# Apple          39
# Lava           36
# Celkon         33
# Spice          30
# Karbonn        29
# Coolpad        22
# BlackBerry     22
# Microsoft      22
# OnePlus        22
# Google         15
# Infinix        10
# Name: device_brand, dtype: int64

# %%
df['os'].value_counts()
# Out:
# Android    3214
# Others      137
# Windows      67
# iOS          36
# Name: os, dtype: int64

# %%
df['4g'].value_counts()
# Out:
# yes    2335
# no     1119
# Name: 4g, dtype: int64

# %%
df['5g'].value_counts()
# Out:
# no     3302
# yes     152
# Name: 5g, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

labelfit=le.fit(df["device_brand"])
df["device_brand"]=labelfit.transform(df["device_brand"])
df.head()
# Out:
#    device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0            10  Android        14.50  yes   no            13.0
# 1            10  Android        17.30  yes  yes            13.0
# 2            10  Android        16.69  yes  yes            13.0
# 3            10  Android        25.50  yes  yes            13.0
# 4            10  Android        15.32  yes   no            13.0
#
#    front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0              5.0             64.0  3.0   3020.0   146.0          2020
# 1             16.0            128.0  8.0   4300.0   213.0          2020
# 2              8.0            128.0  8.0   4200.0   213.0          2020
# 3              8.0             64.0  6.0   7250.0   480.0          2020
# 4              8.0             64.0  3.0   5000.0   185.0          2020
#
#    days_used  normalized_used_price  normalized_new_price
# 0        127               4.307572              4.715100
# ...

# %%
df.tail()
# Out:
#       device_brand       os  screen_size   4g  5g  rear_camera_mp  \
# 3449             3  Android        15.34  yes  no            13.0
# 3450             3  Android        15.24  yes  no            13.0
# 3451             1  Android        15.80  yes  no            13.0
# 3452             1  Android        15.80  yes  no            13.0
# 3453             1  Android        12.83  yes  no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 3449              8.0             64.0  6.0   5000.0   190.0          2019
# 3450              8.0            128.0  8.0   4000.0   200.0          2018
# 3451              5.0             32.0  3.0   4000.0   165.0          2020
# 3452              5.0             32.0  2.0   4000.0   160.0          2020
# 3453              5.0             16.0  2.0   4000.0   168.0          2020
#
#       days_used  normalized_used_price  normalized_new_price
# ...

# %%
df['device_brand'].unique()
# Out:
# array([10, 24,  9, 11, 12, 15, 16, 14, 17, 18, 20, 21, 22, 23, 26, 27, 30,
#        32, 33,  2,  3,  6,  0,  1,  4,  5,  7,  8, 13, 19, 25, 28, 29, 31])

# %%
labelfit.inverse_transform([3])
# Out:
# array(['Asus'], dtype=object)

# %%
data=pd.get_dummies(df,columns=['4g','5g','os'],drop_first=True)
data.head()
# Out:
#    device_brand  screen_size  rear_camera_mp  front_camera_mp  \
# 0            10        14.50            13.0              5.0
# 1            10        17.30            13.0             16.0
# 2            10        16.69            13.0              8.0
# 3            10        25.50            13.0              8.0
# 4            10        15.32            13.0              8.0
#
#    internal_memory  ram  battery  weight  release_year  days_used  \
# 0             64.0  3.0   3020.0   146.0          2020        127
# 1            128.0  8.0   4300.0   213.0          2020        325
# 2            128.0  8.0   4200.0   213.0          2020        162
# 3             64.0  6.0   7250.0   480.0          2020        345
# 4             64.0  3.0   5000.0   185.0          2020        293
#
#    normalized_used_price  normalized_new_price  4g_yes  5g_yes  os_Others  \
# 0               4.307572              4.715100       1       0          0
# ...

# %%
data.dtypes
# Out:
# device_brand               int64
# screen_size              float64
# rear_camera_mp           float64
# front_camera_mp          float64
# internal_memory          float64
# ram                      float64
# battery                  float64
# weight                   float64
# release_year               int64
# days_used                  int64
# normalized_used_price    float64
# normalized_new_price     float64
# 4g_yes                     uint8
# 5g_yes                     uint8
# os_Others                  uint8
# os_Windows                 uint8
# os_iOS                     uint8
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3454 entries, 0 to 3453
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   device_brand           3454 non-null   int64
#  1   screen_size            3454 non-null   float64
#  2   rear_camera_mp         3454 non-null   float64
#  3   front_camera_mp        3454 non-null   float64
#  4   internal_memory        3454 non-null   float64
#  5   ram                    3454 non-null   float64
#  6   battery                3454 non-null   float64
#  7   weight                 3454 non-null   float64
#  8   release_year           3454 non-null   int64
#  9   days_used              3454 non-null   int64
#  10  normalized_used_price  3454 non-null   float64
#  11  normalized_new_price   3454 non-null   float64
#  12  4g_yes                 3454 non-null   uint8
#  13  5g_yes                 3454 non-null   uint8
# ...

# %%
x=data.drop(['normalized_new_price'],axis=1)
x.head()
# Out:
#    device_brand  screen_size  rear_camera_mp  front_camera_mp  \
# 0            10        14.50            13.0              5.0
# 1            10        17.30            13.0             16.0
# 2            10        16.69            13.0              8.0
# 3            10        25.50            13.0              8.0
# 4            10        15.32            13.0              8.0
#
#    internal_memory  ram  battery  weight  release_year  days_used  \
# 0             64.0  3.0   3020.0   146.0          2020        127
# 1            128.0  8.0   4300.0   213.0          2020        325
# 2            128.0  8.0   4200.0   213.0          2020        162
# 3             64.0  6.0   7250.0   480.0          2020        345
# 4             64.0  3.0   5000.0   185.0          2020        293
#
#    normalized_used_price  4g_yes  5g_yes  os_Others  os_Windows  os_iOS
# 0               4.307572       1       0          0           0       0
# ...

# %%
y=data['normalized_new_price']

# %%
y.head()
# Out:
# 0    4.715100
# 1    5.519018
# 2    5.884631
# 3    5.630961
# 4    4.947837
# Name: normalized_new_price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# #Model Building

# %% [markdown]
# linearregression

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
x_train=sd.fit_transform(x_train)
x_test=sd.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=regressor.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse1=mean_squared_error(y_test,y_pred1)
mse1
# Out:
# 0.12126928470694727

# %%
training_score1=regressor.score(x_train,y_train)
training_score1
# Out:
# 0.7561237907287162

# %%
testing_score1=regressor.score(x_test,y_test)
testing_score1
# Out:
# 0.7744397110770174

# %%
#without std
y_pred1=regressor.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse1=mean_squared_error(y_test,y_pred1)
mse1
# Out:
# 0.12126928470694727

# %%
training_score1=regressor.score(x_train,y_train)
training_score1
# Out:
# 0.7561237907287162

# %%
testing_score1=regressor.score(x_test,y_test)
testing_score1
# Out:
# 0.7744397110770174

# %% [markdown]
# knn

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred2=model.predict(x_test)
y_pred2
# Out:
# array([5.39101989, 5.72069458, 5.7862956 , 6.09883891, 3.34022918,
#        6.03638304, 5.00043427, 4.42483165, 4.99481869, 4.57418054,
#        5.0555018 , 5.24962826, 5.04395085, 6.58965801, 5.52729867,
#        5.11991978, 4.53675398, 5.35084501, 5.75314719, 5.34661027,
#        4.64587256, 3.36633659, 5.13669259, 5.72044225, 4.84682252,
#        5.19720293, 5.01628131, 4.60407028, 7.02724736, 5.12220905,
#        6.4048997 , 5.41648558, 5.22610565, 5.35054329, 4.74498469,
#        5.57371898, 5.57091425, 4.79554169, 5.33311888, 4.70530814,
#        4.93667906, 5.19837025, 4.27231499, 5.35261692, 5.72660477,
#        5.87325294, 4.98317753, 3.11682774, 5.17364629, 6.15221477,
#        5.01504625, 5.44237465, 5.16638764, 4.4249711 , 4.16694196,
#        5.97897913, 5.66098637, 4.54426543, 4.05734406, 4.93274843,
#        6.4735017 , 5.953443  , 4.97584868, 4.6984365 , 5.19173627,
#        5.43955041, 5.36122843, 4.95597016, 5.95931629, 5.45570582,
# ...

# %%
from sklearn.metrics import mean_squared_error
mse2=mean_squared_error(y_test,y_pred2)
mse2
# Out:
# 0.11847688332216501

# %%
training_score2=model.score(x_train,y_train)
training_score2
# Out:
# 0.8376371033387581

# %%
testing_score1=model.score(x_test,y_test)
testing_score1
# Out:
# 0.7796335642828187

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred2)
# Out:
# 0.7796335642828187

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
x_train=sd.fit_transform(x_train)
x_test=sd.fit_transform(x_test)

# %%
y_pred2=model.predict(x_test)
y_pred2
# Out:
# array([5.39101989, 5.72069458, 5.7862956 , 6.09883891, 3.34022918,
#        6.03638304, 5.00043427, 4.42483165, 4.99481869, 4.57418054,
#        5.0555018 , 5.24962826, 5.04395085, 6.58965801, 5.52729867,
#        5.11991978, 4.53675398, 5.35084501, 5.75314719, 5.34661027,
#        4.64587256, 3.36633659, 5.13669259, 5.72044225, 4.84682252,
#        5.19720293, 5.01628131, 4.60407028, 7.02724736, 5.12220905,
#        6.4048997 , 5.41648558, 5.22610565, 5.35054329, 4.74498469,
#        5.57371898, 5.57091425, 4.79554169, 5.33311888, 4.70530814,
#        4.93667906, 5.19837025, 4.27231499, 5.35261692, 5.72660477,
#        5.87325294, 4.98317753, 3.11682774, 5.17364629, 6.15221477,
#        5.01504625, 5.44237465, 5.16638764, 4.4249711 , 4.16694196,
#        5.97897913, 5.66098637, 4.54426543, 4.05734406, 4.93274843,
#        6.4735017 , 5.953443  , 4.97584868, 4.6984365 , 5.19173627,
#        5.43955041, 5.36122843, 4.95597016, 5.95931629, 5.45570582,
# ...

# %%
training_score2=model.score(x_train,y_train)
training_score2
# Out:
# 0.8376371033387581

# %%
testing_score1=model.score(x_test,y_test)
testing_score1
# Out:
# 0.7796335642828187

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
model1=RandomForestRegressor()
model1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred3=model1.predict(x_test)
y_pred3
# Out:
# array([5.19259902, 5.69651516, 5.76279837, 5.71738873, 3.13129228,
#        5.8673923 , 4.98444388, 4.66848755, 4.93650884, 4.79588777,
#        4.99700307, 5.40394497, 5.14061836, 6.44290571, 5.39520867,
#        4.96183923, 4.40708968, 5.52168453, 5.63290011, 5.26816449,
#        4.59644859, 3.4450857 , 5.11098487, 5.94735761, 5.05806722,
#        4.76314343, 5.12999256, 4.49027993, 6.13070722, 5.33179737,
#        6.69813071, 5.54059303, 5.22576283, 5.27724288, 4.74622397,
#        5.49503266, 5.8776274 , 4.66285219, 5.19813319, 4.76258523,
#        5.0678221 , 5.29361742, 4.02940008, 5.66241092, 5.79763668,
#        6.33806251, 5.17744567, 2.97107588, 5.03029393, 6.32670807,
#        5.19546094, 5.27318164, 5.1970863 , 4.22445245, 3.99414576,
#        6.3265902 , 5.33871692, 4.52169685, 3.46468245, 4.68005926,
#        6.70896514, 6.64974119, 4.98413882, 4.56299365, 5.44289735,
#        5.06344281, 5.45178735, 4.96689557, 6.14335119, 5.65655318,
# ...

# %%
training_score3=model1.score(x_train,y_train)
training_score3
# Out:
# 0.9730382881262137

# %%
testing_score3=model1.score(x_test,y_test)
testing_score3
# Out:
# 0.8320941837818683

# %%
mse3=mean_squared_error(y_test,y_pred3)
mse3
# Out:
# 0.09027217657919163

# %% [markdown]
# decision tree

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
from sklearn.tree import DecisionTreeRegressor

model2=DecisionTreeRegressor()
model2.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred4=model2.predict(x_test)
y_pred4
# Out:
# array([5.30051495, 5.80733135, 5.38674025, 5.75215986, 3.02334744,
#        5.70314894, 4.60537017, 4.79231343, 4.51950336, 4.69711106,
#        4.86205794, 5.59653128, 5.13485682, 6.20564808, 5.00803191,
#        5.14848236, 4.25773811, 5.5219408 , 5.69954016, 5.2450748 ,
#        4.60656921, 2.95543098, 5.19151136, 6.11372643, 4.60216568,
#        4.86499276, 5.29174582, 4.38127635, 6.21126251, 6.1108463 ,
#        7.00317454, 5.69970752, 5.19484396, 5.18816762, 4.58557954,
#        5.68102549, 6.68567366, 4.69811393, 5.29886721, 4.86968598,
#        4.87213922, 5.52549278, 4.26366531, 5.70521478, 5.52254034,
#        5.70581374, 5.48151354, 2.95543098, 4.70727541, 6.43004201,
#        5.30131288, 5.56218051, 5.44665116, 4.37877134, 4.05958057,
#        6.21396789, 5.24681352, 4.41061409, 3.6846204 , 4.69198988,
#        6.80336096, 6.71476501, 4.60507018, 4.60656921, 4.79620368,
#        4.79098563, 5.66926004, 4.94128522, 6.10726785, 5.94670251,
# ...

# %%
mse4=mean_squared_error(y_test,y_pred4)
mse4
# Out:
# 0.1808415793612706

# %%
training_score4=model2.score(x_train,y_train)
training_score4
# Out:
# 1.0

# %%
testing_score4=model2.score(x_test,y_test)
testing_score4
# Out:
# 0.663635528249472

# %% [markdown]
# support vector machine(svm)

# %%
from sklearn.svm import SVR
svr=SVR(kernel="rbf")
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred5=svr.predict(x_test)

# %%
mse5=mean_squared_error(y_test,y_pred5)
mse5
# Out:
# 0.3050803348700393

# %%
training_score5=svr.score(x_train,y_train)
training_score5
# Out:
# 0.3873687412105583

# %%
testing_score5=svr.score(x_test,y_test)
testing_score5
# Out:
# 0.4325520378527954

# %% [markdown]
# xgboost

# %%
from xgboost import XGBRegressor

# %%
xg=XGBRegressor()
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred6=xg.predict(x_test)
y_pred6
# Out:
# array([5.2802134, 5.773851 , 5.802419 , 5.679475 , 3.0937836, 5.7489233,
#        4.8544035, 4.5389223, 5.260425 , 4.9994426, 5.0193553, 5.503051 ,
#        5.392763 , 6.4977794, 5.5270734, 4.9128294, 4.1644998, 5.529719 ,
#        5.5811377, 5.4467583, 4.9217973, 3.4063632, 5.436715 , 6.0078607,
#        5.273411 , 4.828182 , 5.015629 , 4.602059 , 6.194225 , 5.1752086,
#        6.818618 , 5.5436254, 5.2921524, 5.251738 , 4.6235714, 5.2017884,
#        5.652389 , 4.7214723, 5.210285 , 4.971271 , 4.9574785, 5.3773785,
#        4.3130093, 5.5877295, 5.7379637, 6.1698556, 5.234041 , 2.9935703,
#        4.9878097, 6.450991 , 5.227737 , 5.214938 , 5.190443 , 4.152849 ,
#        3.9849124, 6.420384 , 5.5741267, 4.3773384, 3.44396  , 4.5539584,
#        6.793826 , 6.638999 , 5.037126 , 4.754584 , 5.2604446, 4.9430237,
#        5.492819 , 4.8405647, 6.297606 , 5.5523605, 5.8023753, 6.0333204,
#        5.3566217, 5.3728056, 5.8545084, 4.9843383, 5.35648  , 5.163355 ,
# ...

# %%
training_score6=xg.score(x_train,y_train)
training_score6
# Out:
# 0.981870852171857

# %%
testing_score6=xg.score(x_test,y_test)
testing_score6
# Out:
# 0.8420386748311061

# %%
mse6=mean_squared_error(y_test,y_pred6)
mse6
# Out:
# 0.08492566225225054

# %% [markdown]
# Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
import sklearn.ensemble as ensm
adb=AdaBoostRegressor(n_estimators=10,learning_rate=1.0)

# %%
adb.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(n_estimators=10)

# %%
y_pred7=adb.predict(x_test)

# %%
training_score7=adb.score(x_train,y_train)
training_score7
# Out:
# 0.7221014034436215

# %%
testing_score7=adb.score(x_test,y_test)
testing_score7
# Out:
# 0.7589929622754836

# %%
mse7=mean_squared_error(y_test,y_pred7)
mse7
# Out:
# 0.12957400974145675

# %% [markdown]
# #Conclusion

# %% [markdown]
# linear regression:
#
#
#                 training=0.7561
#                 testing=0.7813
#
#
# knn:
#
#
#                  training=0.8376
#                  testing=0.7796
#
# decision tree:
#
#
#                   training=1.0
#                   testing=0.65
#
#
# random forest:
#
#                   training=0.9728
#                   testing=0.8330
#
#
# svm:
#
#                   training=0.3873
#                   testing=0.4325
#
# xgboost:
#
#                   training=0.9818
#                   testing=0.8410
#
#
# adaboost:
#
#                   training=0.7163
#                   testing=0.7537

# %% [markdown]
# here random forest best model

# %% [markdown]
# Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from warnings import filterwarnings
filterwarnings("ignore")

# %%
rfg=RandomForestRegressor()

# %%
param_grid={'n_estimators':[30,50,70,90],'max_features':['sqrt','log2',None],'max_depth':[80,90,100],'max_leaf_nodes':[3,6,9]}

# %%
grid_search=GridSearchCV(estimator=rfg,param_grid=param_grid,cv=3)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [80, 90, 100],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [3, 6, 9],
#                          'n_estimators': [30, 50, 70, 90]})

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_depth=80, max_features=None, max_leaf_nodes=9,
#                       n_estimators=70)

# %%
#updating the model

model_grid=RandomForestRegressor(max_depth=90,max_features=None,max_leaf_nodes=9,n_estimators=70)

# %%
model_grid.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=90, max_features=None, max_leaf_nodes=9,
#                       n_estimators=70)

# %%
y_pred9=model_grid.predict(x_test)

# %%
mse9=mean_squared_error(y_test,y_pred9)
mse9
# Out:
# 0.13124638591223642

# %%
training_score9=model_grid.score(x_train,y_train)
training_score9
# Out:
# 0.7154181943781683

# %%
testing_score9=model_grid.score(x_test,y_test)
testing_score9
# Out:
# 0.7558823506050961
